# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
import seaborn as sns
from datetime import date

# %%
#filename1 = '/Users/galvanize/downloads/zillow-prize-1/properties_2017.csv'
filename1 = 'properties_2017.csv'
#filename2 = 'dataframe_all_timestamps.csv'

# %%
#df = pd.read_csv('/Users/galvanize/downloads/zillow-prize-1/properties_2017.csv')
zill = pd.read_csv('/Users/galvanize/downloads/zillow-prize-1/properties_2017.csv', encoding= 'latin-1')
#df_all_timestamps = pd.read_csv('dataframe_all_timestamps.csv')
# Out:
# /Users/galvanize/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (22,49,58,59,62,63,65,67,69,71,73,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.options.display.max_columns = 999

# %%
zill[zill['county_name'].isnull() == False].head(20)
# Out:
#     parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 5   10898347                    NaN                       NaN           NaN
# 6   10933547                    NaN                       NaN           NaN
# 7   10940747                    NaN                       NaN           NaN
# 8   10954547                    NaN                       NaN           NaN
# 9   10976347                    NaN                       NaN           NaN
# 10  11070347                    1.0                       NaN           NaN
# 11  11073947                    NaN                       NaN           NaN
# 12  11114347                    NaN                       NaN           NaN
# 13  11116947                    NaN                       NaN           NaN
# 14  11142747                    NaN                       NaN           NaN
# 15  11193347                    NaN                       NaN           NaN
# ...

# %%
zill.info
# Out:
# <bound method DataFrame.info of          parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 0        10754147                    NaN                       NaN
# 1        10759547                    NaN                       NaN
# 2        10843547                    NaN                       NaN
# 3        10859147                    NaN                       NaN
# 4        10879947                    NaN                       NaN
# ...           ...                    ...                       ...
# 1048570  11720573                    NaN                       NaN
# 1048571  11720635                    NaN                       NaN
# 1048572  11720658                    NaN                       NaN
# 1048573  11721148                    NaN                       NaN
# 1048574  11721271                    NaN                       NaN
#
#          basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# ...

# %%
crim = pd.read_csv('/Users/galvanize/Downloads/hci_crime_752_pl_co_re_ca_2000-2013_21oct15(1).csv', encoding= 'latin-1')
# Out:
# /Users/galvanize/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
crim[crim['county_name'].isnull() == False].head()
# Out:
#   ind_id                                 ind_definition  reportyear  \
# 5    752  Number of Violent Crimes per 1,000 Population      2000.0
# 6    752  Number of Violent Crimes per 1,000 Population      2000.0
# 7    752  Number of Violent Crimes per 1,000 Population      2000.0
# 8    752  Number of Violent Crimes per 1,000 Population      2000.0
# 9    752  Number of Violent Crimes per 1,000 Population      2000.0
#
#    race_eth_code race_eth_name geotype  geotypevalue  geoname  county_fips  \
# 5            9.0         Total      CO        6001.0  Alameda       6001.0
# 6            9.0         Total      CO        6001.0  Alameda       6001.0
# 7            9.0         Total      CO        6001.0  Alameda       6001.0
# 8            9.0         Total      CO        6001.0  Alameda       6001.0
# 9            9.0         Total      CO        6001.0  Alameda       6001.0
#
#   county_name  region_code region_name  strata_name_code  \
# ...

# %%
crim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49227 entries, 0 to 49226
# Data columns (total 27 columns):
# ind_id                    49227 non-null object
# ind_definition            49226 non-null object
# reportyear                49226 non-null float64
# race_eth_code             49226 non-null float64
# race_eth_name             49226 non-null object
# geotype                   49226 non-null object
# geotypevalue              49226 non-null float64
# geoname                   49226 non-null object
# county_fips               48176 non-null float64
# county_name               48176 non-null object
# region_code               49156 non-null float64
# region_name               49156 non-null object
# strata_name_code          49226 non-null float64
# strata_name               49226 non-null object
# strata_level_name_code    49226 non-null float64
# strata_level_name         49226 non-null object
# numerator                 32293 non-null float64
# ...

# %%
zproj = pd.merge(zill,crim)
zproj.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  11662353                    1.0                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          2.0         2.0                  NaN                   11.0
#
#    calculatedbathnbr  decktypeid  finishedfloor1squarefeet  \
# 0                2.0         NaN                       NaN
#
#    calculatedfinishedsquarefeet  finishedsquarefeet12  finishedsquarefeet13  \
# 0                        3535.0                3535.0                   NaN
#
#    finishedsquarefeet15  finishedsquarefeet50  finishedsquarefeet6  fips  \
# 0                   NaN                   NaN                  NaN  6037
#
#    fireplacecnt  fullbathcnt  garagecarcnt  garagetotalsqft hashottuborspa  \
# 0           NaN          2.0           NaN              NaN            NaN
#
#    heatingorsystemtypeid  latitude  longitude  lotsizesquarefeet  poolcnt  \
# ...

# %%
formula = 'structuretaxvaluedollarcnt ~ rate + county_name'

fitted_model = smf.ols(formula=formula, data=zill).fit()
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ...
# Dep. Variable:     structuretaxvaluedollarcnt   R-squared:                       0.006
# Model:                                    OLS   Adj. R-squared:                 -0.002
# Method:                         Least Squares   F-statistic:                    0.7504
# Date:                        Thu, 09 Jan 2020   Prob (F-statistic):              0.920
# Time:                                17:24:44   Log-Likelihood:                -97324.
# No. Observations:                        6971   AIC:                         1.948e+05
# Df Residuals:                            6912   BIC:                         1.952e+05
# Df Model:                                  58
# Covariance Type:                    nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
formula = 'structuretaxvaluedollarcnt ~ county_name + strata_level_name'

fitted_model = smf.ols(formula=formula, data=zill).fit()
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ...
# Dep. Variable:     structuretaxvaluedollarcnt   R-squared:                       0.003
# Model:                                    OLS   Adj. R-squared:                  0.001
# Method:                         Least Squares   F-statistic:                     2.021
# Date:                        Thu, 09 Jan 2020   Prob (F-statistic):           3.59e-06
# Time:                                17:24:52   Log-Likelihood:            -6.7829e+05
# No. Observations:                       47326   AIC:                         1.357e+06
# Df Residuals:                           47263   BIC:                         1.357e+06
# Df Model:                                  62
# Covariance Type:                    nonrobust
# ...
#                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# Link to Tableau visualizations: https://public.tableau.com/profile/alisha.mclean#!/vizhome/Zillow_California_Crime_Stats/Sheet6?publish=yes

# %%
#modDfObj = zill.apply(lambda x : x + crim)
 
#print("Modified Dataframe by applying lambda function on each column:")
#print(modDfObj)
#kernel kept dying when this ran

# %%
formula = 'structuretaxvaluedollarcnt ~ rate + county_name + poolcnt'

fitted_model = smf.ols(formula=formula, data=zill).fit()
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ...
# Dep. Variable:     structuretaxvaluedollarcnt   R-squared:                       0.027
# Model:                                    OLS   Adj. R-squared:                 -0.018
# Method:                         Least Squares   F-statistic:                    0.5970
# Date:                        Thu, 09 Jan 2020   Prob (F-statistic):              0.993
# Time:                                17:24:57   Log-Likelihood:                -18745.
# No. Observations:                        1304   AIC:                         3.761e+04
# Df Residuals:                            1245   BIC:                         3.791e+04
# Df Model:                                  58
# Covariance Type:                    nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
formula = 'structuretaxvaluedollarcnt ~ rate + county_name + poolcnt + hashottuborspa'

fitted_model = smf.ols(formula=formula, data=zill).fit()
fitted_model.summary()
# Out:
# /Users/galvanize/miniconda3/lib/python3.7/site-packages/statsmodels/base/model.py:1294: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# /Users/galvanize/miniconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# /Users/galvanize/miniconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:901: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# /Users/galvanize/miniconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:1892: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ...
# Dep. Variable:     structuretaxvaluedollarcnt   R-squared:                       0.224
# ...

# %%
formula = 'structuretaxvaluedollarcnt ~ rate + county_name + strata_level_name'

fitted_model = smf.ols(formula=formula, data=zill).fit()
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ...
# Dep. Variable:     structuretaxvaluedollarcnt   R-squared:                       0.006
# Model:                                    OLS   Adj. R-squared:                 -0.002
# Method:                         Least Squares   F-statistic:                    0.7504
# Date:                        Thu, 09 Jan 2020   Prob (F-statistic):              0.920
# Time:                                17:44:42   Log-Likelihood:                -97324.
# No. Observations:                        6971   AIC:                         1.948e+05
# Df Residuals:                            6912   BIC:                         1.952e+05
# Df Model:                                  58
# Covariance Type:                    nonrobust
# ...
#                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
#this was final chosen regression including the crime rate
formula = 'structuretaxvaluedollarcnt ~ rate + county_name + poolcnt + hashottuborspa + strata_level_name'

fitted_model = smf.ols(formula=formula, data=zill).fit()
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ...
# Dep. Variable:     structuretaxvaluedollarcnt   R-squared:                       0.224
# Model:                                    OLS   Adj. R-squared:                 -0.512
# Method:                         Least Squares   F-statistic:                    0.3048
# Date:                        Thu, 09 Jan 2020   Prob (F-statistic):               1.00
# Time:                                17:52:42   Log-Likelihood:                -1094.8
# No. Observations:                          77   AIC:                             2266.
# Df Residuals:                              39   BIC:                             2355.
# Df Model:                                  37
# Covariance Type:                    nonrobust
# ...
#                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
#this was final chosen regression excluding the crime rate
formula = 'structuretaxvaluedollarcnt ~ county_name + poolcnt + hashottuborspa + strata_level_name'

fitted_model = smf.ols(formula=formula, data=zill).fit()
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ...
# Dep. Variable:     structuretaxvaluedollarcnt   R-squared:                       0.171
# Model:                                    OLS   Adj. R-squared:                  0.055
# Method:                         Least Squares   F-statistic:                     1.475
# Date:                        Thu, 09 Jan 2020   Prob (F-statistic):             0.0156
# Time:                                17:54:06   Log-Likelihood:                -7248.7
# No. Observations:                         497   AIC:                         1.462e+04
# Df Residuals:                             435   BIC:                         1.488e+04
# Df Model:                                  61
# Covariance Type:                    nonrobust
# ...
#                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
formula = 'structuretaxvaluedollarcnt ~ county_name + poolcnt + hashottuborspa'

fitted_model = smf.ols(formula=formula, data=zill).fit()
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ...
# Dep. Variable:     structuretaxvaluedollarcnt   R-squared:                       0.160
# Model:                                    OLS   Adj. R-squared:                  0.053
# Method:                         Least Squares   F-statistic:                     1.495
# Date:                        Thu, 09 Jan 2020   Prob (F-statistic):             0.0155
# Time:                                17:55:00   Log-Likelihood:                -7252.1
# No. Observations:                         497   AIC:                         1.462e+04
# Df Residuals:                             440   BIC:                         1.486e+04
# Df Model:                                  56
# Covariance Type:                    nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# ...
